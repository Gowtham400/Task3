# %% [markdown]
# # IMPORT LIBRARIES

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
#Importing Dataset
ds=pd.read_csv("C:\\Cureya\\Employee-Attrition.csv")

#accesing first 6 datavalues
ds.head(6)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
# ...

# %%
#reading the last 5 datavalues
ds.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
#shape of dataset
ds.shape
# Out:
# (1470, 35)

# %%
#all the columns in dataset

ds.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
ds.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#types of datavalues
ds.dtypes.value_counts()
# Out:
# int64     26
# object     9
# dtype: int64

# %%
#checking the duplicate values
ds.duplicated().sum()
# Out:
# 0

# %%
#checking the null values
ds.isnull().values.any()
# Out:
# False

# %%
#modelling the data
ds.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#finding the total attritions
attritions=pd.DataFrame(ds['Attrition'].value_counts())
attritions
# Out:
#      Attrition
# No        1233
# Yes        237

# %%
#bargraph representation
sns.countplot(ds['Attrition'])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
#piechart representation
plt.pie(attritions["Attrition"] , labels = ['No' , 'Yes'] , explode = (0.2,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x1ab14078ee0>,
# ...
#  [Text(-1.136781068348268, 0.6306574368426737, 'No'),
#   Text(0.961891673217765, -0.5336332157899547, 'Yes')])

# %%
plt.subplots(figsize=(14,5))
sns.countplot(x='Age', hue='Attrition', data=ds, palette = 'colorblind')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# ## Correlation

# %%
corr=ds.corr()
corr
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
#correlation matrix
plt.figure(figsize=(14,10))
plt.title("Correlation Matrix",fontsize=20)
sns.heatmap(ds.corr(), annot=True, fmt='.0%' )
# Out:
# <AxesSubplot:title={'center':'Correlation Matrix'}>

# %%
#dropping the columns having same datavalues
ds.drop(['Age','EmployeeCount','EmployeeNumber','StandardHours'],axis=1, inplace=True)

# %%
#encode binary variables
ds['OverTime'] = ds['OverTime'].map({'No':0,'Yes':1})
ds['Gender'] = ds['Gender'].map({'Male':0,'Female':1})

#encode categorical columns which are ordinal, use labelEncoding
cat_cols = ['BusinessTravel','Department','EducationField','JobRole','MaritalStatus']
for col in cat_cols:
    map_dict = {k:i for i, k in enumerate(ds[col].value_counts().index,0)}
    ds[col] = ds[col].map(map_dict)

# %%
ds.head()
# Out:
#   Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0       Yes               0       1102           1                 1
# 1        No               1        279           0                 8
# 2       Yes               0       1373           0                 2
# 3        No               1       1392           0                 3
# 4        No               0        591           0                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0          2               0                        2       1          94
# 1          1               0                        3       0          61
# 2          2               4                        4       0          92
# 3          4               0                        4       1          56
# 4          1               1                        1       0          40
#
#    ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
categorical_features = ds.select_dtypes(include=[np.object]).columns
print("total categorical_features",len(categorical_features))
# Out:
# total categorical_features 2

# %%
ds[categorical_features].head()
# Out:
#   Attrition Over18
# 0       Yes      Y
# 1        No      Y
# 2       Yes      Y
# 3        No      Y
# 4        No      Y

# %%
# Business Travel
ds['BusinessTravel'].value_counts()
# Out:
# 0    1043
# 1     277
# 2     150
# Name: BusinessTravel, dtype: int64

# %%
#plotting Attrition wrt BusinessTravel
plt.figure(figsize=(8,5))
sns.countplot(x='BusinessTravel',hue='Attrition', data=ds, palette='plasma')
plt.title("Attrition wrt BusinessTravel")
plt.show()

# %%
#Department
ds['Department'].value_counts()
# Out:
# 0    961
# 1    446
# 2     63
# Name: Department, dtype: int64

# %%
# Department wrt Attrition
plt.figure(figsize=(8,5))
sns.countplot(x='Department',hue='Attrition', data=ds, palette='rocket')
plt.title("Attrition w.r.t Department")
plt.show()

# %%
#EducationField
ds['EducationField'].value_counts()
# Out:
# 0    606
# 1    464
# 2    159
# 3    132
# 4     82
# 5     27
# Name: EducationField, dtype: int64

# %%
# Department wrt Attrition
plt.figure(figsize=(8,5))
sns.countplot(x='EducationField',hue='Attrition', data=ds, palette='seismic')
plt.title("Attrition w.r.t EducationField")
plt.xticks(rotation=45)
plt.show()

# %%
#Gender
ds['Gender'].value_counts()
# Out:
# 0    882
# 1    588
# Name: Gender, dtype: int64

# %%
# Gender wrt Attrition
plt.figure(figsize=(7,5))
sns.countplot(x='Gender',hue='Attrition', data=ds, palette='plasma')
plt.title("Gender w.r.t Attrition")
plt.legend(loc='best')
plt.show()

# %%
# let's see at which post most people are leaving the jobs
# JobRole
plt.figure(figsize=(8,5))
sns.countplot(x='JobRole',hue='Attrition', data=ds, palette='plasma')
plt.title("JobRole w.r.t Attrition")
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.show()

# %%
# let's also see, how any male and female are Married
pd.crosstab(ds['MaritalStatus'],ds['Gender'])
# Out:
# Gender           0    1
# MaritalStatus
# 0              401  272
# 1              271  199
# 2              210  117

# %%
plt.figure(figsize=(7,5))
sns.countplot(x='OverTime',hue='Attrition', data=ds, palette='plasma')
plt.title("OverTime w.r.t Attrition")
plt.legend(loc='best')
plt.show()

# %%
# how many male and female do overTime
pd.crosstab(ds['OverTime'], ds['Gender'])
# Out:
# Gender      0    1
# OverTime
# 0         646  408
# 1         236  180

# %% [markdown]
# # Train Test Splitting

# %%
from sklearn.preprocessing import LabelEncoder
for column in ds.columns:
    if ds[column].dtype==np.number:
        continue
    else:
        ds[column]=LabelEncoder().fit_transform(ds[column])

# %%
from sklearn.model_selection import train_test_split

# %%
x = ds.drop('Attrition',axis=1)
y = ds['Attrition']

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)
x_train.head()
# Out:
#      BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 338               0        295           1                 4          2
# 363               0        159           1                 4          2
# 759               0        437           2                23          3
# 793               0        502           0                14          1
# 581               0        516           0                 0          2
#
#      EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 338               2                        3       1           0
# 363               2                        3       1           4
# 759               1                        1       0           6
# 793               0                        0       0          20
# 581               0                        3       0           8
#
#      JobInvolvement  ...  PerformanceRating  RelationshipSatisfaction  \
# ...

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
 rf.score(x_train, y_train)
# Out:
# 0.9805636540330418

# %%
pred = rf.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.8526077097505669

# %% [markdown]
# ### Model accuracy with Random Forest Classifier: 85.26%

# %% [markdown]
# # Logistic Regression

# %%
#applying Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_test)

# %%
#computing confusion matrix
from sklearn.metrics import confusion_matrix, accuracy_score
confmat = confusion_matrix(y_pred, y_test)
confmat
# Out:
# array([[365,  68],
#        [  6,   2]], dtype=int64)

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.8321995464852607

# %% [markdown]
# ### Model accuracy with LogisticRegression: 83.21%

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8117913832199547

# %% [markdown]
# ### Model accuracy with Naive Bayes: 81.17%
